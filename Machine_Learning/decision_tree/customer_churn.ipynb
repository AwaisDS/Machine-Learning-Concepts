# %%
import pandas as pd

# %%
df=pd.read_csv('customer_churn_data.csv')

# %%
df.head()
# Out:
#   customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0   CUST0000    Male              0      No        Yes      23           No
# 1   CUST0001  Female              0     Yes         No      43           No
# 2   CUST0002    Male              1      No         No      51          Yes
# 3   CUST0003    Male              1      No         No      72          Yes
# 4   CUST0004    Male              1      No         No      25          Yes
#
#       MultipleLines InternetService       OnlineSecurity  ...  \
# 0  No phone service              No  No internet service  ...
# 1  No phone service             DSL                  Yes  ...
# 2                No             DSL                   No  ...
# 3               Yes             DSL                  Yes  ...
# 4               Yes             DSL                   No  ...
#
#       DeviceProtection          TechSupport          StreamingTV  \
# 0  No internet service  No internet service  No internet service
# ...

# %%
df.drop('customerID' ,axis=1,inplace=True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0    Male              0      No        Yes      23           No
# 1  Female              0     Yes         No      43           No
# 2    Male              1      No         No      51          Yes
# 3    Male              1      No         No      72          Yes
# 4    Male              1      No         No      25          Yes
#
#       MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 0  No phone service              No  No internet service  No internet service
# 1  No phone service             DSL                  Yes                   No
# 2                No             DSL                   No                  Yes
# 3               Yes             DSL                  Yes                   No
# 4               Yes             DSL                   No                   No
#
#       DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
df.Contract.unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
for col in df.columns:
    print(f"columns name: {col}")
    print(df[col].unique())
# Out:
# columns name: gender
# ['Male' 'Female']
# columns name: SeniorCitizen
# [0 1]
# columns name: Partner
# ['No' 'Yes']
# columns name: Dependents
# ['Yes' 'No']
# columns name: tenure
# [23 43 51 72 25 35 17 18 27 15 69 42 34 48  8 10  5 26 62 13  9 20 57 24
#  33 60 64 30 14 19 71 59 67 44 32 11  2 68 40 46  4 38 63 29 70 52 55 66
#  31 61 36 37 47 22 39 58  7 65  6 45  1 56 21 16 49 41  3 12 53 28 50 54]
# columns name: PhoneService
# ['No' 'Yes']
# columns name: MultipleLines
# ['No phone service' 'No' 'Yes']
# columns name: InternetService
# ['No' 'DSL' 'Fiber optic']
# columns name: OnlineSecurity
# ['No internet service' 'Yes' 'No']
# columns name: OnlineBackup
# ['No internet service' 'No' 'Yes']
# columns name: DeviceProtection
# ['No internet service' 'Yes' 'No']
# columns name: TechSupport
# ['No internet service' 'No' 'Yes']
# columns name: StreamingTV
# ['No internet service' 'Yes' 'No']
# columns name: StreamingMovies
# ['No internet service' 'No' 'Yes']
# ...

# %%
def preprocess_data(df):
    """
    Cleans and encodes the DataFrame:
    - Replaces 'No internet service' and 'No phone service' with 'No'
    - Converts 'Yes'/'No' to 1/0
    - Converts 'Male'/'Female' in 'gender' column to 1/0
    
    Parameters:
        df (pd.DataFrame): The input DataFrame
        
    Returns:
        pd.DataFrame: The processed DataFrame
    """
    
    # Step 1: Replace service-related 'No internet service' and 'No phone service' with 'No'
    service_cols = [
        'MultipleLines', 'OnlineSecurity', 'OnlineBackup', 
        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies'
    ]
    for col in service_cols:
        df[col] = df[col].replace({'No internet service': 'No', 'No phone service': 'No'})
    
    # Step 2: Convert 'Yes'/'No' to 1/0 in applicable columns
    yes_no_cols = [col for col in df.columns if df[col].isin(['Yes', 'No']).all()]
    for col in yes_no_cols:
        df[col] = df[col].map({'Yes': 1, 'No': 0})
    
    # Step 3: Convert 'gender' to binary (Male: 1, Female: 0)
    if 'gender' in df.columns:
        df['gender'] = df['gender'].map({'Male': 1, 'Female': 0})
    
    return df

# %%
df=preprocess_data(df)

# %%
df.head()
# Out:
#    gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# 0       1              0        0           1      23             0
# 1       0              0        1           0      43             0
# 2       1              1        0           0      51             1
# 3       1              1        0           0      72             1
# 4       1              1        0           0      25             1
#
#    MultipleLines InternetService  OnlineSecurity  OnlineBackup  \
# 0              0              No               0             0
# 1              0             DSL               1             0
# 2              0             DSL               0             1
# 3              1             DSL               1             0
# 4              1             DSL               0             0
#
#    DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# 0                 0            0            0                0
# ...

# %% [markdown]
# ### Now encoding
